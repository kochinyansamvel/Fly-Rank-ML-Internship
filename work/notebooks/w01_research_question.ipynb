# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kochinyansamvel/Fly-Rank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?
#
# I want to choose freestyle lane in specifically Growth/Recovery/Momentum Prediction. My question will be "Can behavior in the prior 90 days predict whether a page declines or recovers in the next 30, and which features matter most?". The reason why I want to choose this specific question is that I think it will be a good practice for my ML skills.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?
#
# My work should improve the understanding over pages. Is there a need to refresh the page or it should be kept as it is. Fly Ranks SEO improvement team will act on my insights. Wrong recomendation can be bad for websites perfomance*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
url = 'https://github.com/kochinyansamvel/Fly-Rank-ML-Internship/blob/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)

# how many pages are declining with real demand behind them?
declining_with_demand = df[(df.trend_direction == "down") & (df.impressions_90d >= 100)]
print(declining_with_demand)
# how many rank decently but still under-capture clicks?
low_ctr_visible = df[(df.impressions_90d >= 500) & df.avg_position.between(0, 20, inclusive="right") & (df.ctr < 0.5)]
print(low_ctr_visible)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_2229/3591102126.py in <cell line: 0>()
#       3 import pandas as pd
#       4 url = 'https://github.com/kochinyansamvel/Fly-Rank-ML-Internship/blob/main/data/raw/content_refresh_anonymized.csv'
# ----> 5 df = pd.read_csv(url)
#       6
#       7 # how many pages are declining with real demand behind them?
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# I can claim which signals are significant for the performance BUT I can't claim causation

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
